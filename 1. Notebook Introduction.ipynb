# %%
# %sql
select * from x

# %% [markdown]
# # Comments

# %%
# %sql
select "Hello World!" ;
select "Hello !";

# %%
# %fs ls dbfs:/databricks-datasets/adult/

# %%
# %python 
# %restart_python

# %%
# %python
# %pip list

# %%
display(dbutils.fs.ls("dbfs:/databricks-datasets/adult/"))
